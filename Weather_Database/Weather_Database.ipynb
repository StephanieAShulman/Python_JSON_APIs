# %% [markdown]
# # Weather Database

# %% [markdown]
# ### Create a set of 2,000 random latitudes and longitudes

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create arrays (declare as variables) of latitudes and longitudes for storing data
#  Generate random combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
# Pack as pairs by zipping them
lat_lngs = zip(lats, lngs)
# Printed: zip object in memory
lat_lngs

# %%
# Unpack lat_lngs zip object into a list so that the set of random latitudes and longitudes is created once only.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Generate Random World Cities

# %%
# Use the citipy module to determine city based on latitude and longitude.
# Note: A python file imported into another python script does not require the .py extension be added during import.
from citipy import citipy

# %%
# Create a list for holding the citites
cities = []
# Identify the nearest city for each lat and lng combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique then add it to the cities list (note: there may be duplicates, so need 'unique')
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient number of cities
len(cities)
# Out:
# 763

# %% [markdown]
# ### Perform an API call with OpenWeatherMap

# %% [markdown]
# #### Psuedocode
# 1. Import dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as weather data for each city is found.
#   * Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. Make an API request for each city.
# 7. Parse the JSON weather data for the following:
#   * Latitude and longitude
#   * Maximum temperature
#   * Percent humidity
#   * Percent cloudiness
#   * Wind speed
#   * Weather description (eg: clouds, fog, light rain, clear sky)
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# Import Requests library and weather_api_key
# Build the basic url for OpenWeatherMap

# Import the requests library and configure API key
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Define the URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
# Initialize at 1 to have the set to start at 1 when the first iteration of the logging for each recorded response starts 
record_count = 1
set_count = 1

# Now iterate through list of cities and begin building the URL for each city while grouping records in sets of 50
#  The index marks when 50 is reached.
# Tell the program to then pause 60 seconds as OWM API allows only 60 call/min on free tier.
#   Pause prevents timeout error
# Retrieve city from cities list and add to city_url with indexing

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "appid=" + weather_api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # NOTE: pass here is bad coding practice; just for learning at this point

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | bristol
# Processing Record 10 of Set 1 | sabya
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | vostok
# Processing Record 15 of Set 1 | caravelas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | lata
# Processing Record 18 of Set 1 | granada
# Processing Record 19 of Set 1 | nemuro
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | kasamwa
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | santa cruz cabralia
# Processing Record 25 of Set 1 | cape elizabeth
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | port blair
# Processing Record 28 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | surgut
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | kieta
# Processing Record 38 of Set 1 | polovinnoye
# Processing Record 39 of Set 1 | barraute
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | mezhdurechensk
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | port hardy
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | tual
# Processing Record 4 of Set 2 | buraydah
# Processing Record 5 of Set 2 | homer
# Processing Record 6 of Set 2 | mwinilunga
# Processing Record 7 of Set 2 | sindor
# Processing Record 8 of Set 2 | cabedelo
# Processing Record 9 of Set 2 | komsomolskiy
# Processing Record 10 of Set 2 | marzuq
# Processing Record 11 of Set 2 | acapulco
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | rocha
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | sunbury
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | xiaoweizhai
# Processing Record 24 of Set 2 | chantada
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | gravdal
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | plettenberg bay
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | vysokogornyy
# Processing Record 32 of Set 2 | petropavl
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | evensk
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | menongue
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | kautokeino
# Processing Record 44 of Set 2 | ust-tsilma
# Processing Record 45 of Set 2 | yumen
# Processing Record 46 of Set 2 | inta
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | broken hill
# Processing Record 49 of Set 2 | kholtoson
# Processing Record 50 of Set 2 | fairview
# Processing Record 1 of Set 3 | hamilton
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | grand gaube
# Processing Record 10 of Set 3 | san rafael
# Processing Record 11 of Set 3 | batouri
# Processing Record 12 of Set 3 | huarmey
# Processing Record 13 of Set 3 | bilibino
# Processing Record 14 of Set 3 | progreso
# Processing Record 15 of Set 3 | linxia
# Processing Record 16 of Set 3 | key west
# Processing Record 17 of Set 3 | piet retief
# Processing Record 18 of Set 3 | bom jesus
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | ginda
# Processing Record 21 of Set 3 | gizo
# Processing Record 22 of Set 3 | kailua
# Processing Record 23 of Set 3 | blackfoot
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | kysyl-syr
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | katsuura
# Processing Record 28 of Set 3 | luau
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | noumea
# Processing Record 31 of Set 3 | antalaha
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | juneau
# Processing Record 35 of Set 3 | birao
# Processing Record 36 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 3 | makakilo city
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | benjamin aceval
# Processing Record 40 of Set 3 | haapiti
# Processing Record 41 of Set 3 | sangar
# Processing Record 42 of Set 3 | krasnoselkup
# Processing Record 43 of Set 3 | atar
# Processing Record 44 of Set 3 | maltahohe
# Processing Record 45 of Set 3 | sorong
# Processing Record 46 of Set 3 | kunzelsau
# Processing Record 47 of Set 3 | zhezkazgan
# Processing Record 48 of Set 3 | devrek
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | brooks
# Processing Record 3 of Set 4 | nueva gerona
# Processing Record 4 of Set 4 | jinchang
# Processing Record 5 of Set 4 | uray
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | santa cruz
# Processing Record 11 of Set 4 | olhao
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | bekhtery
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | verkhnevilyuysk
# Processing Record 18 of Set 4 | olafsvik
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | nabire
# Processing Record 21 of Set 4 | avarua
# Processing Record 22 of Set 4 | valparaiso
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | zyryanka
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | porto novo
# Processing Record 28 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 4 | tuatapere
# Processing Record 30 of Set 4 | reitz
# Processing Record 31 of Set 4 | lagoa
# Processing Record 32 of Set 4 | fredericksburg
# Processing Record 33 of Set 4 | kaabong
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | khandyga
# Processing Record 36 of Set 4 | baraya
# Processing Record 37 of Set 4 | leshukonskoye
# Processing Record 38 of Set 4 | zwedru
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | povenets
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | masuguru
# Processing Record 46 of Set 4 | yerbogachen
# Processing Record 47 of Set 4 | kraksaan
# Processing Record 48 of Set 4 | kloulklubed
# Processing Record 49 of Set 4 | ixtapa
# Processing Record 50 of Set 4 | emporia
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | amet
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | batemans bay
# Processing Record 5 of Set 5 | bolshaya glushitsa
# Processing Record 6 of Set 5 | okhotsk
# Processing Record 7 of Set 5 | rio novo
# Processing Record 8 of Set 5 | tyup
# Processing Record 9 of Set 5 | dalvik
# Processing Record 10 of Set 5 | puerto del rosario
# Processing Record 11 of Set 5 | seoul
# Processing Record 12 of Set 5 | puerto escondido
# Processing Record 13 of Set 5 | myrhorod
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | guadalupe y calvo
# Processing Record 16 of Set 5 | shingu
# Processing Record 17 of Set 5 | iwanai
# Processing Record 18 of Set 5 | jamestown
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | pacifica
# Processing Record 21 of Set 5 | tosya
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | tomatlan
# Processing Record 24 of Set 5 | tahta
# Processing Record 25 of Set 5 | tynda
# Processing Record 26 of Set 5 | ruwi
# Processing Record 27 of Set 5 | churapcha
# Processing Record 28 of Set 5 | adra
# Processing Record 29 of Set 5 | chase
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | namatanai
# Processing Record 32 of Set 5 | port alfred
# Processing Record 33 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | koygorodok
# Processing Record 36 of Set 5 | neiafu
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | alto araguaia
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | ayorou
# Processing Record 42 of Set 5 | madang
# Processing Record 43 of Set 5 | ketchikan
# Processing Record 44 of Set 5 | sault sainte marie
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | sevlievo
# Processing Record 47 of Set 5 | half moon bay
# Processing Record 48 of Set 5 | maniitsoq
# Processing Record 49 of Set 5 | port angeles
# Processing Record 50 of Set 5 | burica
# City not found. Skipping...
# Processing Record 1 of Set 6 | kitimat
# Processing Record 2 of Set 6 | vallenar
# Processing Record 3 of Set 6 | viedma
# Processing Record 4 of Set 6 | berlevag
# Processing Record 5 of Set 6 | liwale
# Processing Record 6 of Set 6 | miri
# Processing Record 7 of Set 6 | kovdor
# Processing Record 8 of Set 6 | del rio
# Processing Record 9 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 6 | boa vista
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | russell
# Processing Record 13 of Set 6 | carutapera
# Processing Record 14 of Set 6 | la mana
# Processing Record 15 of Set 6 | sisimiut
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | launceston
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | itambacuri
# Processing Record 20 of Set 6 | talaya
# Processing Record 21 of Set 6 | port hedland
# Processing Record 22 of Set 6 | bandarbeyla
# Processing Record 23 of Set 6 | imbituba
# Processing Record 24 of Set 6 | aasiaat
# Processing Record 25 of Set 6 | cuenca
# Processing Record 26 of Set 6 | starobaltachevo
# Processing Record 27 of Set 6 | solnechnyy
# Processing Record 28 of Set 6 | aksarka
# Processing Record 29 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 6 | gat
# Processing Record 31 of Set 6 | monticello
# Processing Record 32 of Set 6 | lesnoy
# Processing Record 33 of Set 6 | kaeng khlo
# City not found. Skipping...
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | bam
# Processing Record 37 of Set 6 | williston
# Processing Record 38 of Set 6 | beira
# Processing Record 39 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | comodoro rivadavia
# Processing Record 42 of Set 6 | savannah bight
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | miraflores
# Processing Record 45 of Set 6 | lower hutt
# Processing Record 46 of Set 6 | dunedin
# Processing Record 47 of Set 6 | sterling
# Processing Record 48 of Set 6 | paamiut
# Processing Record 49 of Set 6 | esperance
# Processing Record 50 of Set 6 | casma
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 2 of Set 7 | polunochnoye
# Processing Record 3 of Set 7 | bati
# Processing Record 4 of Set 7 | tarakan
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | skjervoy
# Processing Record 7 of Set 7 | vestmanna
# Processing Record 8 of Set 7 | pierre
# Processing Record 9 of Set 7 | la tuque
# Processing Record 10 of Set 7 | tamworth
# Processing Record 11 of Set 7 | vicencia
# Processing Record 12 of Set 7 | kupang
# Processing Record 13 of Set 7 | asht
# City not found. Skipping...
# Processing Record 14 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 7 | mnogovershinnyy
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | qinhuangdao
# Processing Record 18 of Set 7 | trairi
# Processing Record 19 of Set 7 | coquimbo
# Processing Record 20 of Set 7 | popondetta
# Processing Record 21 of Set 7 | hanover
# Processing Record 22 of Set 7 | gazni
# City not found. Skipping...
# Processing Record 23 of Set 7 | hay river
# Processing Record 24 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 7 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 7 | kaniama
# Processing Record 27 of Set 7 | rypefjord
# Processing Record 28 of Set 7 | cortez
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | mataram
# Processing Record 32 of Set 7 | ponta do sol
# Processing Record 33 of Set 7 | matara
# Processing Record 34 of Set 7 | leibnitz
# Processing Record 35 of Set 7 | marsa matruh
# Processing Record 36 of Set 7 | shenjiamen
# Processing Record 37 of Set 7 | hurghada
# Processing Record 38 of Set 7 | ascension
# Processing Record 39 of Set 7 | marystown
# Processing Record 40 of Set 7 | agirish
# Processing Record 41 of Set 7 | weyburn
# Processing Record 42 of Set 7 | sabha
# Processing Record 43 of Set 7 | port macquarie
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | metsavan
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | honningsvag
# Processing Record 48 of Set 7 | zhigalovo
# Processing Record 49 of Set 7 | semey
# Processing Record 50 of Set 7 | kpandae
# Processing Record 1 of Set 8 | kota kinabalu
# Processing Record 2 of Set 8 | lismore
# Processing Record 3 of Set 8 | chicaman
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | kimbe
# Processing Record 6 of Set 8 | jalu
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | ancud
# Processing Record 9 of Set 8 | ferrol
# Processing Record 10 of Set 8 | jiwani
# Processing Record 11 of Set 8 | erzin
# Processing Record 12 of Set 8 | ban dung
# Processing Record 13 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 8 | nelson bay
# Processing Record 15 of Set 8 | tucuman
# Processing Record 16 of Set 8 | dingle
# Processing Record 17 of Set 8 | matlock
# Processing Record 18 of Set 8 | nacozari
# Processing Record 19 of Set 8 | ramshir
# Processing Record 20 of Set 8 | cairns
# Processing Record 21 of Set 8 | eureka
# Processing Record 22 of Set 8 | belmonte
# Processing Record 23 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 8 | winona
# Processing Record 25 of Set 8 | chake chake
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | iqaluit
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | sochi
# Processing Record 30 of Set 8 | krechevitsy
# Processing Record 31 of Set 8 | matamoros
# Processing Record 32 of Set 8 | quelimane
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | andros town
# Processing Record 35 of Set 8 | davila
# Processing Record 36 of Set 8 | padang
# Processing Record 37 of Set 8 | ostersund
# Processing Record 38 of Set 8 | warri
# Processing Record 39 of Set 8 | hithadhoo
# Processing Record 40 of Set 8 | haines junction
# Processing Record 41 of Set 8 | acarau
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 45 of Set 8 | durban
# Processing Record 46 of Set 8 | maraa
# Processing Record 47 of Set 8 | alofi
# Processing Record 48 of Set 8 | eirunepe
# Processing Record 49 of Set 8 | cherskiy
# Processing Record 50 of Set 8 | porto belo
# Processing Record 1 of Set 9 | tilichiki
# Processing Record 2 of Set 9 | san quintin
# Processing Record 3 of Set 9 | ilo
# Processing Record 4 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 9 | ucluelet
# Processing Record 6 of Set 9 | saint george
# Processing Record 7 of Set 9 | saravan
# Processing Record 8 of Set 9 | vanimo
# Processing Record 9 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 9 | san carlos de bariloche
# Processing Record 11 of Set 9 | hwange
# Processing Record 12 of Set 9 | oistins
# Processing Record 13 of Set 9 | izmit
# Processing Record 14 of Set 9 | mezen
# Processing Record 15 of Set 9 | puerto narino
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | raudeberg
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | hobyo
# Processing Record 20 of Set 9 | ambulu
# Processing Record 21 of Set 9 | bagula
# Processing Record 22 of Set 9 | charlestown
# Processing Record 23 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | bereda
# Processing Record 25 of Set 9 | kleinmachnow
# Processing Record 26 of Set 9 | fort nelson
# Processing Record 27 of Set 9 | pinega
# Processing Record 28 of Set 9 | rio casca
# Processing Record 29 of Set 9 | general roca
# Processing Record 30 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 9 | mao
# Processing Record 33 of Set 9 | paracuru
# Processing Record 34 of Set 9 | ponta delgada
# Processing Record 35 of Set 9 | la romana
# Processing Record 36 of Set 9 | batagay
# Processing Record 37 of Set 9 | omsukchan
# Processing Record 38 of Set 9 | tarauaca
# Processing Record 39 of Set 9 | kedrovyy
# Processing Record 40 of Set 9 | lupiro
# Processing Record 41 of Set 9 | dhidhdhoo
# Processing Record 42 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 9 | ashqelon
# Processing Record 45 of Set 9 | xai-xai
# Processing Record 46 of Set 9 | hakvik
# City not found. Skipping...
# Processing Record 47 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 9 | quang ngai
# Processing Record 49 of Set 9 | tukan
# Processing Record 50 of Set 9 | asau
# Processing Record 1 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 10 | bogota
# Processing Record 3 of Set 10 | camara de lobos
# Processing Record 4 of Set 10 | botwood
# Processing Record 5 of Set 10 | coihaique
# Processing Record 6 of Set 10 | pestyaki
# Processing Record 7 of Set 10 | veshenskaya
# Processing Record 8 of Set 10 | ardesen
# Processing Record 9 of Set 10 | coahuayana
# Processing Record 10 of Set 10 | benoy
# Processing Record 11 of Set 10 | ulaangom
# Processing Record 12 of Set 10 | koungheul
# Processing Record 13 of Set 10 | kangaatsiaq
# Processing Record 14 of Set 10 | kalininskaya
# Processing Record 15 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 16 of Set 10 | mogadishu
# Processing Record 17 of Set 10 | taoudenni
# Processing Record 18 of Set 10 | molina
# Processing Record 19 of Set 10 | panalingaan
# Processing Record 20 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 10 | sobolevo
# Processing Record 22 of Set 10 | longyearbyen
# Processing Record 23 of Set 10 | gold coast
# Processing Record 24 of Set 10 | santa maria
# Processing Record 25 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 27 of Set 10 | oktyabrskiy
# Processing Record 28 of Set 10 | daru
# Processing Record 29 of Set 10 | emba
# Processing Record 30 of Set 10 | anadyr
# Processing Record 31 of Set 10 | saldanha
# Processing Record 32 of Set 10 | krasnovishersk
# Processing Record 33 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 10 | laguna
# Processing Record 35 of Set 10 | manokwari
# Processing Record 36 of Set 10 | tefe
# Processing Record 37 of Set 10 | paranavai
# Processing Record 38 of Set 10 | kyshtovka
# Processing Record 39 of Set 10 | bilma
# Processing Record 40 of Set 10 | la ronge
# Processing Record 41 of Set 10 | bonavista
# Processing Record 42 of Set 10 | campbellton
# Processing Record 43 of Set 10 | podosinovets
# Processing Record 44 of Set 10 | doha
# Processing Record 45 of Set 10 | sur
# Processing Record 46 of Set 10 | taman
# Processing Record 47 of Set 10 | kendari
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | ken caryl
# Processing Record 50 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 11 | kollo
# Processing Record 2 of Set 11 | ous
# Processing Record 3 of Set 11 | kaeo
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | gheorghe lazar
# Processing Record 6 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 7 of Set 11 | sinnamary
# Processing Record 8 of Set 11 | boffa
# Processing Record 9 of Set 11 | warwick
# Processing Record 10 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 11 | northam
# Processing Record 12 of Set 11 | uniontown
# Processing Record 13 of Set 11 | gvardeysk
# Processing Record 14 of Set 11 | camopi
# Processing Record 15 of Set 11 | conceicao do araguaia
# Processing Record 16 of Set 11 | constitucion
# Processing Record 17 of Set 11 | gari
# Processing Record 18 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 11 | kinsale
# Processing Record 20 of Set 11 | morondava
# Processing Record 21 of Set 11 | miles city
# Processing Record 22 of Set 11 | orange cove
# Processing Record 23 of Set 11 | ust-kuyga
# Processing Record 24 of Set 11 | brenham
# Processing Record 25 of Set 11 | itarema
# Processing Record 26 of Set 11 | fiche
# Processing Record 27 of Set 11 | leningradskiy
# Processing Record 28 of Set 11 | mahanoro
# Processing Record 29 of Set 11 | gloggnitz
# Processing Record 30 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 11 | lessines
# Processing Record 32 of Set 11 | sola
# Processing Record 33 of Set 11 | umba
# Processing Record 34 of Set 11 | chengde
# Processing Record 35 of Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 36 of Set 11 | biak
# Processing Record 37 of Set 11 | nador
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | nouadhibou
# Processing Record 40 of Set 11 | letlhakane
# Processing Record 41 of Set 11 | alta floresta
# Processing Record 42 of Set 11 | san cristobal
# Processing Record 43 of Set 11 | nioro
# Processing Record 44 of Set 11 | imeni poliny osipenko
# Processing Record 45 of Set 11 | vuktyl
# Processing Record 46 of Set 11 | vaitape
# Processing Record 47 of Set 11 | goundam
# Processing Record 48 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 11 | oranjemund
# Processing Record 50 of Set 11 | zaranj
# Processing Record 1 of Set 12 | chimoio
# Processing Record 2 of Set 12 | grindavik
# Processing Record 3 of Set 12 | san benito
# Processing Record 4 of Set 12 | ta khmau
# Processing Record 5 of Set 12 | kamienna gora
# Processing Record 6 of Set 12 | aquiraz
# Processing Record 7 of Set 12 | bud
# Processing Record 8 of Set 12 | prachin buri
# Processing Record 9 of Set 12 | abonnema
# Processing Record 10 of Set 12 | ilhabela
# Processing Record 11 of Set 12 | pangnirtung
# Processing Record 12 of Set 12 | barrhead
# Processing Record 13 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | hualmay
# Processing Record 16 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 17 of Set 12 | jiayuguan
# Processing Record 18 of Set 12 | waterloo
# Processing Record 19 of Set 12 | mareeba
# Processing Record 20 of Set 12 | sundargarh
# Processing Record 21 of Set 12 | erdenet
# Processing Record 22 of Set 12 | chandbali
# Processing Record 23 of Set 12 | atasu
# Processing Record 24 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | bukachacha
# Processing Record 26 of Set 12 | douentza
# Processing Record 27 of Set 12 | bhalki
# Processing Record 28 of Set 12 | robertsganj
# Processing Record 29 of Set 12 | kolokani
# Processing Record 30 of Set 12 | kupino
# Processing Record 31 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 33 of Set 12 | amudat
# Processing Record 34 of Set 12 | panguna
# Processing Record 35 of Set 12 | leticia
# Processing Record 36 of Set 12 | dutlwe
# Processing Record 37 of Set 12 | poya
# Processing Record 38 of Set 12 | sao sebastiao
# Processing Record 39 of Set 12 | san felipe
# Processing Record 40 of Set 12 | mecca
# Processing Record 41 of Set 12 | masty
# Processing Record 42 of Set 12 | morehead
# Processing Record 43 of Set 12 | say
# Processing Record 44 of Set 12 | te anau
# Processing Record 45 of Set 12 | tabou
# Processing Record 46 of Set 12 | pedernales
# Processing Record 47 of Set 12 | cabras
# Processing Record 48 of Set 12 | yar-sale
# Processing Record 49 of Set 12 | tazovskiy
# Processing Record 50 of Set 12 | vila franca do campo
# Processing Record 1 of Set 13 | dolores
# Processing Record 2 of Set 13 | mingaora
# Processing Record 3 of Set 13 | auki
# Processing Record 4 of Set 13 | pumiao
# Processing Record 5 of Set 13 | salalah
# Processing Record 6 of Set 13 | fresno
# Processing Record 7 of Set 13 | santa cruz del sur
# Processing Record 8 of Set 13 | batagay-alyta
# Processing Record 9 of Set 13 | magomeni
# Processing Record 10 of Set 13 | huntsville
# Processing Record 11 of Set 13 | shache
# Processing Record 12 of Set 13 | hailar
# Processing Record 13 of Set 13 | kaoma
# Processing Record 14 of Set 13 | charters towers
# Processing Record 15 of Set 13 | bintulu
# Processing Record 16 of Set 13 | altay
# Processing Record 17 of Set 13 | shadrinsk
# Processing Record 18 of Set 13 | dongsheng
# Processing Record 19 of Set 13 | havoysund
# Processing Record 20 of Set 13 | dormidontovka
# Processing Record 21 of Set 13 | palestine
# Processing Record 22 of Set 13 | rafaela
# Processing Record 23 of Set 13 | richards bay
# Processing Record 24 of Set 13 | necochea
# Processing Record 25 of Set 13 | kutum
# Processing Record 26 of Set 13 | meulaboh
# Processing Record 27 of Set 13 | tukrah
# Processing Record 28 of Set 13 | jizan
# Processing Record 29 of Set 13 | mabaruma
# Processing Record 30 of Set 13 | lufilufi
# Processing Record 31 of Set 13 | bonthe
# Processing Record 32 of Set 13 | lysva
# Processing Record 33 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 13 | piranhas
# Processing Record 35 of Set 13 | kapchorwa
# Processing Record 36 of Set 13 | udon thani
# Processing Record 37 of Set 13 | ayr
# Processing Record 38 of Set 13 | hare bay
# Processing Record 39 of Set 13 | elizabeth city
# Processing Record 40 of Set 13 | pochutla
# Processing Record 41 of Set 13 | bucerias
# Processing Record 42 of Set 13 | we
# City not found. Skipping...
# Processing Record 43 of Set 13 | ambilobe
# Processing Record 44 of Set 13 | glendive
# Processing Record 45 of Set 13 | talnakh
# Processing Record 46 of Set 13 | araouane
# Processing Record 47 of Set 13 | gewane
# Processing Record 48 of Set 13 | ballina
# Processing Record 49 of Set 13 | vila velha
# Processing Record 50 of Set 13 | kourou
# Processing Record 1 of Set 14 | opuwo
# Processing Record 2 of Set 14 | smithers
# Processing Record 3 of Set 14 | date
# Processing Record 4 of Set 14 | hervey bay
# Processing Record 5 of Set 14 | paita
# Processing Record 6 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 14 | lincoln
# Processing Record 8 of Set 14 | high level
# Processing Record 9 of Set 14 | rio gallegos
# Processing Record 10 of Set 14 | mitu
# Processing Record 11 of Set 14 | sioux lookout
# Processing Record 12 of Set 14 | antsohihy
# Processing Record 13 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 14 | bonnyville
# Processing Record 15 of Set 14 | caineni
# City not found. Skipping...
# Processing Record 16 of Set 14 | kalmunai
# Processing Record 17 of Set 14 | margate
# Processing Record 18 of Set 14 | malakal
# Processing Record 19 of Set 14 | isangel
# Processing Record 20 of Set 14 | denpasar
# Processing Record 21 of Set 14 | garden city
# Processing Record 22 of Set 14 | sylvania
# Processing Record 23 of Set 14 | hirara
# Processing Record 24 of Set 14 | yantal
# Processing Record 25 of Set 14 | nhulunbuy
# Processing Record 26 of Set 14 | high rock
# Processing Record 27 of Set 14 | port maria
# Processing Record 28 of Set 14 | byron bay
# Processing Record 29 of Set 14 | vangaindrano
# Processing Record 30 of Set 14 | gotsu
# Processing Record 31 of Set 14 | malegaon
# Processing Record 32 of Set 14 | pittsfield
# Processing Record 33 of Set 14 | barstow
# Processing Record 34 of Set 14 | pachino
# Processing Record 35 of Set 14 | taltal
# Processing Record 36 of Set 14 | oyama
# Processing Record 37 of Set 14 | ilembula
# Processing Record 38 of Set 14 | luganville
# Processing Record 39 of Set 14 | verkhnyaya inta
# Processing Record 40 of Set 14 | whyalla
# Processing Record 41 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 14 | vytegra
# Processing Record 43 of Set 14 | dashitou
# Processing Record 44 of Set 14 | pampas
# Processing Record 45 of Set 14 | ovalle
# Processing Record 46 of Set 14 | mehamn
# Processing Record 47 of Set 14 | hays
# Processing Record 48 of Set 14 | makkaveyevo
# Processing Record 49 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 14 | olinda
# Processing Record 1 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 2 of Set 15 | buchanan
# Processing Record 3 of Set 15 | bathsheba
# Processing Record 4 of Set 15 | stornoway
# Processing Record 5 of Set 15 | requena
# Processing Record 6 of Set 15 | dakar
# Processing Record 7 of Set 15 | dovolnoye
# Processing Record 8 of Set 15 | puerto ayacucho
# Processing Record 9 of Set 15 | san policarpo
# Processing Record 10 of Set 15 | camabatela
# Processing Record 11 of Set 15 | vestmannaeyjar
# Processing Record 12 of Set 15 | brisenas
# Processing Record 13 of Set 15 | kaseda
# Processing Record 14 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 15 | soe
# Processing Record 16 of Set 15 | fuyang
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | weiser
# Processing Record 19 of Set 15 | troitsko-pechorsk
# Processing Record 20 of Set 15 | santa rosa
# Processing Record 21 of Set 15 | ust-maya
# Processing Record 22 of Set 15 | yandoon
# City not found. Skipping...
# Processing Record 23 of Set 15 | bella vista
# Processing Record 24 of Set 15 | storforshei
# Processing Record 25 of Set 15 | tessalit
# Processing Record 26 of Set 15 | karratha
# Processing Record 27 of Set 15 | dokka
# Processing Record 28 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 15 | berezovka
# Processing Record 30 of Set 15 | road town
# Processing Record 31 of Set 15 | saint anthony
# Processing Record 32 of Set 15 | kudat
# Processing Record 33 of Set 15 | aykhal
# Processing Record 34 of Set 15 | rock springs
# Processing Record 35 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 15 | zavyalovo
# Processing Record 37 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 15 | pyu
# Processing Record 39 of Set 15 | saint-augustin
# Processing Record 40 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 15 | minab
# Processing Record 42 of Set 15 | walvis bay
# Processing Record 43 of Set 15 | baykalsk
# Processing Record 44 of Set 15 | maxixe
# Processing Record 45 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 46 of Set 15 | biltine
# Processing Record 47 of Set 15 | omboue
# Processing Record 48 of Set 15 | shimoda
# Processing Record 49 of Set 15 | teguise
# Processing Record 50 of Set 15 | luena
# Processing Record 1 of Set 16 | myitkyina
# Processing Record 2 of Set 16 | yambio
# Processing Record 3 of Set 16 | douglas
# Processing Record 4 of Set 16 | heinola
# Processing Record 5 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 16 | tateyama
# Processing Record 7 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 16 | mineiros
# Processing Record 9 of Set 16 | obala
# Processing Record 10 of Set 16 | burns lake
# Processing Record 11 of Set 16 | chemal
# Processing Record 12 of Set 16 | sri aman
# Processing Record 13 of Set 16 | maragogi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get a count of the number of cities retrieved
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(3)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Carnarvon -24.8667  113.6333     78.87        73           0       26.46
# 1       Bethel  41.3712  -73.4140     28.47        72         100        6.91
# 2  Yellowknife  62.4560 -114.3525    -17.45        89          40        5.75
#
#   Country Current Description                 Date
# 0      AU           clear sky  2022-01-24 13:27:16
# 1      US     overcast clouds  2022-01-24 13:27:17
# 2      CA    scattered clouds  2022-01-24 13:27:17

# %%
# Reorder the columns for readability
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Reassign df to new order
city_data_df = city_data_df[new_column_order]
city_data_df.head(3)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Carnarvon      AU -24.8667  113.6333     78.87        73           0
# 1       Bethel      US  41.3712  -73.4140     28.47        72         100
# 2  Yellowknife      CA  62.4560 -114.3525    -17.45        89          40
#
#    Wind Speed Current Description
# 0       26.46           clear sky
# 1        6.91     overcast clouds
# 2        5.75    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
